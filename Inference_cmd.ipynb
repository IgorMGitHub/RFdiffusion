# %% [markdown]
# https://github.com/RosettaCommons/RFdiffusion

# %%
from scripts import tools as t

# %%
# Basic execution - an unconditional monomer
t.backup_folder('./test_outputs')
# !./scripts/run_inference.py 'contigmap.contigs=[150-150]' inference.output_prefix=test_outputs/test inference.num_designs=10
# Out:
# /home/coder/project/rfdiffusion/util.py:253: UserWarning: Using torch.cross without specifying the dim arg is deprecated.
# Please either pass the dim explicitly or simply use torch.linalg.cross.
# The default value of dim will change to agree with that of linalg.cross in a future release. (Triggered internally at ../aten/src/ATen/native/Cross.cpp:62.)
#   Z = torch.cross(Xn, Yn)
# /home/coder/.local/lib/python38-conda-cuda/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:104: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:128: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dZ):
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:177: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:207: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *dZ):
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:287: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:304: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dZ):
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:352: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:371: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *dZ):
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:431: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:467: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_out):
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:498: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:535: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *grad_out):
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:566: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:575: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dy):
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:595: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:603: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dy):
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:666: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:692: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.local/lib/python38-conda-cuda/site-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# /home/coder/project/rfdiffusion/Track_module.py:236: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# [2024-08-30 12:38:37,669][__main__][INFO] - Found GPU with device_name NVIDIA A100 80GB PCIe MIG 2g.20gb. Will run RFdiffusion on NVIDIA A100 80GB PCIe MIG 2g.20gb
# Reading models from /home/coder/project/rfdiffusion/inference/../../models
# [2024-08-30 12:38:37,669][rfdiffusion.inference.model_runners][INFO] - Reading checkpoint from /home/coder/project/rfdiffusion/inference/../../models/Base_ckpt.pt
# This is inf_conf.ckpt_path
# /home/coder/project/rfdiffusion/inference/../../models/Base_ckpt.pt
# /home/coder/project/rfdiffusion/inference/model_runners.py:181: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.ckpt  = torch.load(
# Assembling -model, -diffuser and -preprocess configs from checkpoint
# USING MODEL CONFIG: self._conf[model][n_extra_block] = 4
# USING MODEL CONFIG: self._conf[model][n_main_block] = 32
# USING MODEL CONFIG: self._conf[model][n_ref_block] = 4
# USING MODEL CONFIG: self._conf[model][d_msa] = 256
# USING MODEL CONFIG: self._conf[model][d_msa_full] = 64
# USING MODEL CONFIG: self._conf[model][d_pair] = 128
# USING MODEL CONFIG: self._conf[model][d_templ] = 64
# USING MODEL CONFIG: self._conf[model][n_head_msa] = 8
# USING MODEL CONFIG: self._conf[model][n_head_pair] = 4
# USING MODEL CONFIG: self._conf[model][n_head_templ] = 4
# USING MODEL CONFIG: self._conf[model][d_hidden] = 32
# USING MODEL CONFIG: self._conf[model][d_hidden_templ] = 32
# USING MODEL CONFIG: self._conf[model][p_drop] = 0.15
# USING MODEL CONFIG: self._conf[model][SE3_param_full] = {'num_layers': 1, 'num_channels': 32, 'num_degrees': 2, 'n_heads': 4, 'div': 4, 'l0_in_features': 8, 'l0_out_features': 8, 'l1_in_features': 3, 'l1_out_features': 2, 'num_edge_features': 32}
# USING MODEL CONFIG: self._conf[model][SE3_param_topk] = {'num_layers': 1, 'num_channels': 32, 'num_degrees': 2, 'n_heads': 4, 'div': 4, 'l0_in_features': 64, 'l0_out_features': 64, 'l1_in_features': 3, 'l1_out_features': 2, 'num_edge_features': 64}
# USING MODEL CONFIG: self._conf[model][freeze_track_motif] = False
# USING MODEL CONFIG: self._conf[model][use_motif_timestep] = True
# USING MODEL CONFIG: self._conf[diffuser][T] = 50
# USING MODEL CONFIG: self._conf[diffuser][b_0] = 0.01
# USING MODEL CONFIG: self._conf[diffuser][b_T] = 0.07
# USING MODEL CONFIG: self._conf[diffuser][schedule_type] = linear
# USING MODEL CONFIG: self._conf[diffuser][so3_type] = igso3
# USING MODEL CONFIG: self._conf[diffuser][crd_scale] = 0.25
# USING MODEL CONFIG: self._conf[diffuser][so3_schedule_type] = linear
# USING MODEL CONFIG: self._conf[diffuser][min_b] = 1.5
# USING MODEL CONFIG: self._conf[diffuser][max_b] = 2.5
# USING MODEL CONFIG: self._conf[diffuser][min_sigma] = 0.02
# USING MODEL CONFIG: self._conf[diffuser][max_sigma] = 1.5
# USING MODEL CONFIG: self._conf[preprocess][sidechain_input] = False
# USING MODEL CONFIG: self._conf[preprocess][motif_sidechain_input] = True
# USING MODEL CONFIG: self._conf[preprocess][d_t1d] = 22
# USING MODEL CONFIG: self._conf[preprocess][d_t2d] = 44
# USING MODEL CONFIG: self._conf[preprocess][prob_self_cond] = 0.5
# USING MODEL CONFIG: self._conf[preprocess][str_self_cond] = True
# USING MODEL CONFIG: self._conf[preprocess][predict_previous] = False
# [2024-08-30 12:38:53,386][rfdiffusion.inference.model_runners][INFO] - Loading checkpoint.
# [2024-08-30 12:38:53,566][rfdiffusion.diffusion][INFO] - Using cached IGSO3.
# /home/coder/.local/lib/python38-conda-cuda/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# Successful diffuser __init__
# [2024-08-30 12:38:53,588][__main__][INFO] - Making design test_outputs/test_0
# [2024-08-30 12:38:53,593][rfdiffusion.inference.model_runners][INFO] - Using contig: ['150-150']
# With this beta schedule (linear schedule, beta_0 = 0.04, beta_T = 0.28), alpha_bar_T = 0.00013696050154976547
# [2024-08-30 12:38:53,767][rfdiffusion.inference.model_runners][INFO] - Sequence init: ------------------------------------------------------------------------------------------------------------------------------------------------------
# /home/coder/.conda/envs/SE3NGL/lib/python3.9/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# [2024-08-30 12:38:57,648][rfdiffusion.inference.model_runners][INFO] - Timestep 50, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:38:58,928][rfdiffusion.inference.model_runners][INFO] - Timestep 49, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:00,267][rfdiffusion.inference.model_runners][INFO] - Timestep 48, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:01,460][rfdiffusion.inference.model_runners][INFO] - Timestep 47, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:02,557][rfdiffusion.inference.model_runners][INFO] - Timestep 46, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:03,637][rfdiffusion.inference.model_runners][INFO] - Timestep 45, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:04,649][rfdiffusion.inference.model_runners][INFO] - Timestep 44, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:05,662][rfdiffusion.inference.model_runners][INFO] - Timestep 43, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:06,744][rfdiffusion.inference.model_runners][INFO] - Timestep 42, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:07,779][rfdiffusion.inference.model_runners][INFO] - Timestep 41, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:08,839][rfdiffusion.inference.model_runners][INFO] - Timestep 40, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:09,860][rfdiffusion.inference.model_runners][INFO] - Timestep 39, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:10,941][rfdiffusion.inference.model_runners][INFO] - Timestep 38, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:11,961][rfdiffusion.inference.model_runners][INFO] - Timestep 37, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:13,044][rfdiffusion.inference.model_runners][INFO] - Timestep 36, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:14,569][rfdiffusion.inference.model_runners][INFO] - Timestep 35, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:15,648][rfdiffusion.inference.model_runners][INFO] - Timestep 34, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:17,071][rfdiffusion.inference.model_runners][INFO] - Timestep 33, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:18,172][rfdiffusion.inference.model_runners][INFO] - Timestep 32, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:19,270][rfdiffusion.inference.model_runners][INFO] - Timestep 31, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:20,360][rfdiffusion.inference.model_runners][INFO] - Timestep 30, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:21,469][rfdiffusion.inference.model_runners][INFO] - Timestep 29, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:22,587][rfdiffusion.inference.model_runners][INFO] - Timestep 28, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:23,670][rfdiffusion.inference.model_runners][INFO] - Timestep 27, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:24,757][rfdiffusion.inference.model_runners][INFO] - Timestep 26, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:25,847][rfdiffusion.inference.model_runners][INFO] - Timestep 25, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:26,865][rfdiffusion.inference.model_runners][INFO] - Timestep 24, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:27,946][rfdiffusion.inference.model_runners][INFO] - Timestep 23, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:29,965][rfdiffusion.inference.model_runners][INFO] - Timestep 22, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:31,042][rfdiffusion.inference.model_runners][INFO] - Timestep 21, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:32,057][rfdiffusion.inference.model_runners][INFO] - Timestep 20, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:33,143][rfdiffusion.inference.model_runners][INFO] - Timestep 19, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:34,157][rfdiffusion.inference.model_runners][INFO] - Timestep 18, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:35,241][rfdiffusion.inference.model_runners][INFO] - Timestep 17, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:36,254][rfdiffusion.inference.model_runners][INFO] - Timestep 16, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:37,341][rfdiffusion.inference.model_runners][INFO] - Timestep 15, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:38,385][rfdiffusion.inference.model_runners][INFO] - Timestep 14, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:39,966][rfdiffusion.inference.model_runners][INFO] - Timestep 13, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:41,150][rfdiffusion.inference.model_runners][INFO] - Timestep 12, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:42,462][rfdiffusion.inference.model_runners][INFO] - Timestep 11, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:43,540][rfdiffusion.inference.model_runners][INFO] - Timestep 10, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:44,557][rfdiffusion.inference.model_runners][INFO] - Timestep 9, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:45,640][rfdiffusion.inference.model_runners][INFO] - Timestep 8, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:47,156][rfdiffusion.inference.model_runners][INFO] - Timestep 7, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:48,229][rfdiffusion.inference.model_runners][INFO] - Timestep 6, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:49,247][rfdiffusion.inference.model_runners][INFO] - Timestep 5, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:51,170][rfdiffusion.inference.model_runners][INFO] - Timestep 4, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:52,266][rfdiffusion.inference.model_runners][INFO] - Timestep 3, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:53,347][rfdiffusion.inference.model_runners][INFO] - Timestep 2, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:56,373][__main__][INFO] - Finished design in 1.05 minutes
# [2024-08-30 12:39:56,374][__main__][INFO] - Making design test_outputs/test_1
# [2024-08-30 12:39:56,378][rfdiffusion.inference.model_runners][INFO] - Using contig: ['150-150']
# With this beta schedule (linear schedule, beta_0 = 0.04, beta_T = 0.28), alpha_bar_T = 0.00013696050154976547
# [2024-08-30 12:39:56,463][rfdiffusion.inference.model_runners][INFO] - Sequence init: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:57,859][rfdiffusion.inference.model_runners][INFO] - Timestep 50, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:58,943][rfdiffusion.inference.model_runners][INFO] - Timestep 49, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:39:59,957][rfdiffusion.inference.model_runners][INFO] - Timestep 48, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:01,171][rfdiffusion.inference.model_runners][INFO] - Timestep 47, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:02,361][rfdiffusion.inference.model_runners][INFO] - Timestep 46, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:03,565][rfdiffusion.inference.model_runners][INFO] - Timestep 45, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:04,669][rfdiffusion.inference.model_runners][INFO] - Timestep 44, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:05,765][rfdiffusion.inference.model_runners][INFO] - Timestep 43, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:06,969][rfdiffusion.inference.model_runners][INFO] - Timestep 42, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:08,065][rfdiffusion.inference.model_runners][INFO] - Timestep 41, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:09,867][rfdiffusion.inference.model_runners][INFO] - Timestep 40, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:10,947][rfdiffusion.inference.model_runners][INFO] - Timestep 39, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:11,965][rfdiffusion.inference.model_runners][INFO] - Timestep 38, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:13,048][rfdiffusion.inference.model_runners][INFO] - Timestep 37, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:14,068][rfdiffusion.inference.model_runners][INFO] - Timestep 36, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:15,147][rfdiffusion.inference.model_runners][INFO] - Timestep 35, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:16,368][rfdiffusion.inference.model_runners][INFO] - Timestep 34, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:17,569][rfdiffusion.inference.model_runners][INFO] - Timestep 33, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:18,663][rfdiffusion.inference.model_runners][INFO] - Timestep 32, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:19,756][rfdiffusion.inference.model_runners][INFO] - Timestep 31, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:21,564][rfdiffusion.inference.model_runners][INFO] - Timestep 30, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:22,642][rfdiffusion.inference.model_runners][INFO] - Timestep 29, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:23,664][rfdiffusion.inference.model_runners][INFO] - Timestep 28, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:25,065][rfdiffusion.inference.model_runners][INFO] - Timestep 27, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:26,267][rfdiffusion.inference.model_runners][INFO] - Timestep 26, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:27,353][rfdiffusion.inference.model_runners][INFO] - Timestep 25, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:28,457][rfdiffusion.inference.model_runners][INFO] - Timestep 24, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:30,355][rfdiffusion.inference.model_runners][INFO] - Timestep 23, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:31,449][rfdiffusion.inference.model_runners][INFO] - Timestep 22, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:32,463][rfdiffusion.inference.model_runners][INFO] - Timestep 21, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:33,543][rfdiffusion.inference.model_runners][INFO] - Timestep 20, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:34,558][rfdiffusion.inference.model_runners][INFO] - Timestep 19, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:35,646][rfdiffusion.inference.model_runners][INFO] - Timestep 18, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:37,174][rfdiffusion.inference.model_runners][INFO] - Timestep 17, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:38,269][rfdiffusion.inference.model_runners][INFO] - Timestep 16, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:39,353][rfdiffusion.inference.model_runners][INFO] - Timestep 15, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:40,416][rfdiffusion.inference.model_runners][INFO] - Timestep 14, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:41,462][rfdiffusion.inference.model_runners][INFO] - Timestep 13, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:42,875][rfdiffusion.inference.model_runners][INFO] - Timestep 12, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:43,971][rfdiffusion.inference.model_runners][INFO] - Timestep 11, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:45,052][rfdiffusion.inference.model_runners][INFO] - Timestep 10, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:46,150][rfdiffusion.inference.model_runners][INFO] - Timestep 9, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:47,174][rfdiffusion.inference.model_runners][INFO] - Timestep 8, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:48,271][rfdiffusion.inference.model_runners][INFO] - Timestep 7, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:49,352][rfdiffusion.inference.model_runners][INFO] - Timestep 6, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:50,877][rfdiffusion.inference.model_runners][INFO] - Timestep 5, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:51,967][rfdiffusion.inference.model_runners][INFO] - Timestep 4, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:53,063][rfdiffusion.inference.model_runners][INFO] - Timestep 3, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:54,160][rfdiffusion.inference.model_runners][INFO] - Timestep 2, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:58,166][__main__][INFO] - Finished design in 1.03 minutes
# [2024-08-30 12:40:58,166][__main__][INFO] - Making design test_outputs/test_2
# [2024-08-30 12:40:58,170][rfdiffusion.inference.model_runners][INFO] - Using contig: ['150-150']
# With this beta schedule (linear schedule, beta_0 = 0.04, beta_T = 0.28), alpha_bar_T = 0.00013696050154976547
# [2024-08-30 12:40:58,192][rfdiffusion.inference.model_runners][INFO] - Sequence init: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:40:59,375][rfdiffusion.inference.model_runners][INFO] - Timestep 50, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:00,468][rfdiffusion.inference.model_runners][INFO] - Timestep 49, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:01,646][rfdiffusion.inference.model_runners][INFO] - Timestep 48, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:03,171][rfdiffusion.inference.model_runners][INFO] - Timestep 47, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:04,245][rfdiffusion.inference.model_runners][INFO] - Timestep 46, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:05,261][rfdiffusion.inference.model_runners][INFO] - Timestep 45, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:06,363][rfdiffusion.inference.model_runners][INFO] - Timestep 44, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:07,446][rfdiffusion.inference.model_runners][INFO] - Timestep 43, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:08,464][rfdiffusion.inference.model_runners][INFO] - Timestep 42, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:09,547][rfdiffusion.inference.model_runners][INFO] - Timestep 41, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:10,565][rfdiffusion.inference.model_runners][INFO] - Timestep 40, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:11,651][rfdiffusion.inference.model_runners][INFO] - Timestep 39, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:12,678][rfdiffusion.inference.model_runners][INFO] - Timestep 38, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:13,760][rfdiffusion.inference.model_runners][INFO] - Timestep 37, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:14,847][rfdiffusion.inference.model_runners][INFO] - Timestep 36, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:15,868][rfdiffusion.inference.model_runners][INFO] - Timestep 35, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:16,964][rfdiffusion.inference.model_runners][INFO] - Timestep 34, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:18,569][rfdiffusion.inference.model_runners][INFO] - Timestep 33, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:19,653][rfdiffusion.inference.model_runners][INFO] - Timestep 32, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:21,580][rfdiffusion.inference.model_runners][INFO] - Timestep 31, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:22,676][rfdiffusion.inference.model_runners][INFO] - Timestep 30, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:23,769][rfdiffusion.inference.model_runners][INFO] - Timestep 29, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:24,857][rfdiffusion.inference.model_runners][INFO] - Timestep 28, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:25,926][rfdiffusion.inference.model_runners][INFO] - Timestep 27, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:26,947][rfdiffusion.inference.model_runners][INFO] - Timestep 26, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:27,966][rfdiffusion.inference.model_runners][INFO] - Timestep 25, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:29,046][rfdiffusion.inference.model_runners][INFO] - Timestep 24, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:30,064][rfdiffusion.inference.model_runners][INFO] - Timestep 23, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:31,148][rfdiffusion.inference.model_runners][INFO] - Timestep 22, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:32,168][rfdiffusion.inference.model_runners][INFO] - Timestep 21, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:33,256][rfdiffusion.inference.model_runners][INFO] - Timestep 20, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:34,352][rfdiffusion.inference.model_runners][INFO] - Timestep 19, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:35,460][rfdiffusion.inference.model_runners][INFO] - Timestep 18, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:36,562][rfdiffusion.inference.model_runners][INFO] - Timestep 17, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:41:38,068][rfdiffusion.inference.model_runners][INFO] - Timestep 16, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# ...
# [2024-08-30 12:47:31,067][rfdiffusion.inference.model_runners][INFO] - Timestep 12, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:32,273][rfdiffusion.inference.model_runners][INFO] - Timestep 11, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:33,879][rfdiffusion.inference.model_runners][INFO] - Timestep 10, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:34,955][rfdiffusion.inference.model_runners][INFO] - Timestep 9, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:35,989][rfdiffusion.inference.model_runners][INFO] - Timestep 8, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:37,082][rfdiffusion.inference.model_runners][INFO] - Timestep 7, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:38,155][rfdiffusion.inference.model_runners][INFO] - Timestep 6, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:39,967][rfdiffusion.inference.model_runners][INFO] - Timestep 5, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:41,031][rfdiffusion.inference.model_runners][INFO] - Timestep 4, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:42,047][rfdiffusion.inference.model_runners][INFO] - Timestep 3, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:43,063][rfdiffusion.inference.model_runners][INFO] - Timestep 2, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:46,110][__main__][INFO] - Finished design in 1.00 minutes
# [2024-08-30 12:47:46,111][__main__][INFO] - Making design test_outputs/test_9
# [2024-08-30 12:47:46,115][rfdiffusion.inference.model_runners][INFO] - Using contig: ['150-150']
# With this beta schedule (linear schedule, beta_0 = 0.04, beta_T = 0.28), alpha_bar_T = 0.00013696050154976547
# [2024-08-30 12:47:46,137][rfdiffusion.inference.model_runners][INFO] - Sequence init: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:47,247][rfdiffusion.inference.model_runners][INFO] - Timestep 50, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:50,271][rfdiffusion.inference.model_runners][INFO] - Timestep 49, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:51,361][rfdiffusion.inference.model_runners][INFO] - Timestep 48, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:52,455][rfdiffusion.inference.model_runners][INFO] - Timestep 47, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:53,578][rfdiffusion.inference.model_runners][INFO] - Timestep 46, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:55,480][rfdiffusion.inference.model_runners][INFO] - Timestep 45, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:56,574][rfdiffusion.inference.model_runners][INFO] - Timestep 44, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:47:57,648][rfdiffusion.inference.model_runners][INFO] - Timestep 43, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:00,172][rfdiffusion.inference.model_runners][INFO] - Timestep 42, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:01,273][rfdiffusion.inference.model_runners][INFO] - Timestep 41, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:02,788][rfdiffusion.inference.model_runners][INFO] - Timestep 40, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:04,070][rfdiffusion.inference.model_runners][INFO] - Timestep 39, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:05,167][rfdiffusion.inference.model_runners][INFO] - Timestep 38, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:06,381][rfdiffusion.inference.model_runners][INFO] - Timestep 37, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:07,575][rfdiffusion.inference.model_runners][INFO] - Timestep 36, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:08,653][rfdiffusion.inference.model_runners][INFO] - Timestep 35, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:09,741][rfdiffusion.inference.model_runners][INFO] - Timestep 34, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:10,769][rfdiffusion.inference.model_runners][INFO] - Timestep 33, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:11,847][rfdiffusion.inference.model_runners][INFO] - Timestep 32, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:12,869][rfdiffusion.inference.model_runners][INFO] - Timestep 31, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:13,951][rfdiffusion.inference.model_runners][INFO] - Timestep 30, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:14,969][rfdiffusion.inference.model_runners][INFO] - Timestep 29, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:16,049][rfdiffusion.inference.model_runners][INFO] - Timestep 28, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:17,071][rfdiffusion.inference.model_runners][INFO] - Timestep 27, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:18,669][rfdiffusion.inference.model_runners][INFO] - Timestep 26, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:19,764][rfdiffusion.inference.model_runners][INFO] - Timestep 25, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:20,849][rfdiffusion.inference.model_runners][INFO] - Timestep 24, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:21,866][rfdiffusion.inference.model_runners][INFO] - Timestep 23, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:23,058][rfdiffusion.inference.model_runners][INFO] - Timestep 22, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:24,847][rfdiffusion.inference.model_runners][INFO] - Timestep 21, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:25,872][rfdiffusion.inference.model_runners][INFO] - Timestep 20, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:26,961][rfdiffusion.inference.model_runners][INFO] - Timestep 19, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:28,044][rfdiffusion.inference.model_runners][INFO] - Timestep 18, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:29,066][rfdiffusion.inference.model_runners][INFO] - Timestep 17, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:30,148][rfdiffusion.inference.model_runners][INFO] - Timestep 16, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:31,261][rfdiffusion.inference.model_runners][INFO] - Timestep 15, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:32,345][rfdiffusion.inference.model_runners][INFO] - Timestep 14, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:33,362][rfdiffusion.inference.model_runners][INFO] - Timestep 13, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:34,868][rfdiffusion.inference.model_runners][INFO] - Timestep 12, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:35,962][rfdiffusion.inference.model_runners][INFO] - Timestep 11, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:37,044][rfdiffusion.inference.model_runners][INFO] - Timestep 10, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:38,061][rfdiffusion.inference.model_runners][INFO] - Timestep 9, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:39,173][rfdiffusion.inference.model_runners][INFO] - Timestep 8, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:41,473][rfdiffusion.inference.model_runners][INFO] - Timestep 7, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:42,593][rfdiffusion.inference.model_runners][INFO] - Timestep 6, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:43,965][rfdiffusion.inference.model_runners][INFO] - Timestep 5, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:45,050][rfdiffusion.inference.model_runners][INFO] - Timestep 4, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:46,069][rfdiffusion.inference.model_runners][INFO] - Timestep 3, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:47,132][rfdiffusion.inference.model_runners][INFO] - Timestep 2, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-30 12:48:51,638][__main__][INFO] - Finished design in 1.09 minutes

# %%
from ngl_tools import *

data_folder = 'test_outputs'
files = listdir(f'./{data_folder}')
files = [item for item in files if item[-3:]=='pdb']

set_data_folder(data_folder)

# %%
interact(ngl_plot,filename=files)
# Out:
# interactive(children=(Dropdown(description='filename', options=('test_9.pdb', 'test_7.pdb', 'test_8.pdb', 'tes…
# <function ngl_tools.ngl_plot(filename)>

# %%
# unconditional monomer generation
t.backup_folder('./examples/example_outputs')
# %cd ./examples
# !./design_unconditional.sh
# %cd ..
# Out:
# /home/coder/project/examples
# /home/coder/project/rfdiffusion/util.py:253: UserWarning: Using torch.cross without specifying the dim arg is deprecated.
# Please either pass the dim explicitly or simply use torch.linalg.cross.
# The default value of dim will change to agree with that of linalg.cross in a future release. (Triggered internally at ../aten/src/ATen/native/Cross.cpp:62.)
#   Z = torch.cross(Xn, Yn)
# /home/coder/.local/lib/python38-conda-cuda/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:104: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:128: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dZ):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:177: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:207: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *dZ):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:287: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:304: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dZ):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:352: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:371: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *dZ):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:431: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:467: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_out):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:498: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:535: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *grad_out):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:566: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:575: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dy):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:595: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:603: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dy):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:666: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:692: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.local/lib/python38-conda-cuda/site-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# /home/coder/project/rfdiffusion/Track_module.py:236: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# [2024-08-29 10:32:26,417][__main__][INFO] - Found GPU with device_name NVIDIA A100 80GB PCIe MIG 2g.20gb. Will run RFdiffusion on NVIDIA A100 80GB PCIe MIG 2g.20gb
# Reading models from /home/coder/project/rfdiffusion/inference/../../models
# [2024-08-29 10:32:26,418][rfdiffusion.inference.model_runners][INFO] - Reading checkpoint from /home/coder/project/rfdiffusion/inference/../../models/Base_ckpt.pt
# This is inf_conf.ckpt_path
# /home/coder/project/rfdiffusion/inference/../../models/Base_ckpt.pt
# /home/coder/project/rfdiffusion/inference/model_runners.py:181: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.ckpt  = torch.load(
# Assembling -model, -diffuser and -preprocess configs from checkpoint
# USING MODEL CONFIG: self._conf[model][n_extra_block] = 4
# USING MODEL CONFIG: self._conf[model][n_main_block] = 32
# USING MODEL CONFIG: self._conf[model][n_ref_block] = 4
# USING MODEL CONFIG: self._conf[model][d_msa] = 256
# USING MODEL CONFIG: self._conf[model][d_msa_full] = 64
# USING MODEL CONFIG: self._conf[model][d_pair] = 128
# USING MODEL CONFIG: self._conf[model][d_templ] = 64
# USING MODEL CONFIG: self._conf[model][n_head_msa] = 8
# USING MODEL CONFIG: self._conf[model][n_head_pair] = 4
# USING MODEL CONFIG: self._conf[model][n_head_templ] = 4
# USING MODEL CONFIG: self._conf[model][d_hidden] = 32
# USING MODEL CONFIG: self._conf[model][d_hidden_templ] = 32
# USING MODEL CONFIG: self._conf[model][p_drop] = 0.15
# USING MODEL CONFIG: self._conf[model][SE3_param_full] = {'num_layers': 1, 'num_channels': 32, 'num_degrees': 2, 'n_heads': 4, 'div': 4, 'l0_in_features': 8, 'l0_out_features': 8, 'l1_in_features': 3, 'l1_out_features': 2, 'num_edge_features': 32}
# USING MODEL CONFIG: self._conf[model][SE3_param_topk] = {'num_layers': 1, 'num_channels': 32, 'num_degrees': 2, 'n_heads': 4, 'div': 4, 'l0_in_features': 64, 'l0_out_features': 64, 'l1_in_features': 3, 'l1_out_features': 2, 'num_edge_features': 64}
# USING MODEL CONFIG: self._conf[model][freeze_track_motif] = False
# USING MODEL CONFIG: self._conf[model][use_motif_timestep] = True
# USING MODEL CONFIG: self._conf[diffuser][T] = 50
# USING MODEL CONFIG: self._conf[diffuser][b_0] = 0.01
# USING MODEL CONFIG: self._conf[diffuser][b_T] = 0.07
# USING MODEL CONFIG: self._conf[diffuser][schedule_type] = linear
# USING MODEL CONFIG: self._conf[diffuser][so3_type] = igso3
# USING MODEL CONFIG: self._conf[diffuser][crd_scale] = 0.25
# USING MODEL CONFIG: self._conf[diffuser][so3_schedule_type] = linear
# USING MODEL CONFIG: self._conf[diffuser][min_b] = 1.5
# USING MODEL CONFIG: self._conf[diffuser][max_b] = 2.5
# USING MODEL CONFIG: self._conf[diffuser][min_sigma] = 0.02
# USING MODEL CONFIG: self._conf[diffuser][max_sigma] = 1.5
# USING MODEL CONFIG: self._conf[preprocess][sidechain_input] = False
# USING MODEL CONFIG: self._conf[preprocess][motif_sidechain_input] = True
# USING MODEL CONFIG: self._conf[preprocess][d_t1d] = 22
# USING MODEL CONFIG: self._conf[preprocess][d_t2d] = 44
# USING MODEL CONFIG: self._conf[preprocess][prob_self_cond] = 0.5
# USING MODEL CONFIG: self._conf[preprocess][str_self_cond] = True
# USING MODEL CONFIG: self._conf[preprocess][predict_previous] = False
# [2024-08-29 10:33:02,682][rfdiffusion.inference.model_runners][INFO] - Loading checkpoint.
# [2024-08-29 10:33:02,858][rfdiffusion.diffusion][INFO] - Using cached IGSO3.
# /home/coder/.local/lib/python38-conda-cuda/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# Successful diffuser __init__
# [2024-08-29 10:33:02,868][__main__][INFO] - Making design example_outputs/design_unconditional_0
# [2024-08-29 10:33:02,873][rfdiffusion.inference.model_runners][INFO] - Using contig: ['100-200']
# With this beta schedule (linear schedule, beta_0 = 0.04, beta_T = 0.28), alpha_bar_T = 0.00013696050154976547
# [2024-08-29 10:33:02,900][rfdiffusion.inference.model_runners][INFO] - Sequence init: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# [2024-08-29 10:33:06,601][rfdiffusion.inference.model_runners][INFO] - Timestep 50, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:10,685][rfdiffusion.inference.model_runners][INFO] - Timestep 49, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:12,571][rfdiffusion.inference.model_runners][INFO] - Timestep 48, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:14,535][rfdiffusion.inference.model_runners][INFO] - Timestep 47, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:15,771][rfdiffusion.inference.model_runners][INFO] - Timestep 46, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:17,468][rfdiffusion.inference.model_runners][INFO] - Timestep 45, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:19,375][rfdiffusion.inference.model_runners][INFO] - Timestep 44, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:24,485][rfdiffusion.inference.model_runners][INFO] - Timestep 43, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:27,567][rfdiffusion.inference.model_runners][INFO] - Timestep 42, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:28,862][rfdiffusion.inference.model_runners][INFO] - Timestep 41, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:31,684][rfdiffusion.inference.model_runners][INFO] - Timestep 40, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:33,185][rfdiffusion.inference.model_runners][INFO] - Timestep 39, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:34,481][rfdiffusion.inference.model_runners][INFO] - Timestep 38, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:35,756][rfdiffusion.inference.model_runners][INFO] - Timestep 37, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:37,617][rfdiffusion.inference.model_runners][INFO] - Timestep 36, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:39,568][rfdiffusion.inference.model_runners][INFO] - Timestep 35, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:42,658][rfdiffusion.inference.model_runners][INFO] - Timestep 34, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:45,655][rfdiffusion.inference.model_runners][INFO] - Timestep 33, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:46,955][rfdiffusion.inference.model_runners][INFO] - Timestep 32, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:50,676][rfdiffusion.inference.model_runners][INFO] - Timestep 31, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:52,073][rfdiffusion.inference.model_runners][INFO] - Timestep 30, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:53,673][rfdiffusion.inference.model_runners][INFO] - Timestep 29, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:54,951][rfdiffusion.inference.model_runners][INFO] - Timestep 28, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:33:56,180][rfdiffusion.inference.model_runners][INFO] - Timestep 27, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:34:01,580][rfdiffusion.inference.model_runners][INFO] - Timestep 26, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:34:02,847][rfdiffusion.inference.model_runners][INFO] - Timestep 25, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:34:05,749][rfdiffusion.inference.model_runners][INFO] - Timestep 24, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:34:07,646][rfdiffusion.inference.model_runners][INFO] - Timestep 23, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:34:08,874][rfdiffusion.inference.model_runners][INFO] - Timestep 22, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:34:11,878][rfdiffusion.inference.model_runners][INFO] - Timestep 21, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:34:13,680][rfdiffusion.inference.model_runners][INFO] - Timestep 20, input to next step: -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:34
rfdiffusion.inference.model_runners][INFO] - Timestep 2, input to next step: ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-08-29 10:46:33,087][__main__][INFO] - Finished design in 1.24 minutes
# /home/coder/project

# %%
# Motif Scaffolding
t.backup_folder('./examples/example_outputs')
# %cd ./examples
# !./design_motifscaffolding.sh
# %cd ..
# Out:
# /home/coder/project/examples
# /home/coder/project/rfdiffusion/util.py:253: UserWarning: Using torch.cross without specifying the dim arg is deprecated.
# Please either pass the dim explicitly or simply use torch.linalg.cross.
# The default value of dim will change to agree with that of linalg.cross in a future release. (Triggered internally at ../aten/src/ATen/native/Cross.cpp:62.)
#   Z = torch.cross(Xn, Yn)
# /home/coder/.local/lib/python38-conda-cuda/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:104: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:128: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dZ):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:177: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:207: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *dZ):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:287: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:304: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dZ):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:352: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:371: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *dZ):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:431: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:467: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_out):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:498: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:535: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *grad_out):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:566: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:575: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dy):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:595: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:603: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dy):
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:666: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/sparse.py:692: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /home/coder/.local/lib/python38-conda-cuda/site-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# /home/coder/project/rfdiffusion/Track_module.py:236: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# [2024-08-29 10:13:52,728][__main__][INFO] - Found GPU with device_name NVIDIA A100 80GB PCIe MIG 2g.20gb. Will run RFdiffusion on NVIDIA A100 80GB PCIe MIG 2g.20gb
# Reading models from /home/coder/project/rfdiffusion/inference/../../models
# [2024-08-29 10:13:52,728][rfdiffusion.inference.model_runners][INFO] - Reading checkpoint from /home/coder/project/rfdiffusion/inference/../../models/Base_ckpt.pt
# This is inf_conf.ckpt_path
# /home/coder/project/rfdiffusion/inference/../../models/Base_ckpt.pt
# /home/coder/project/rfdiffusion/inference/model_runners.py:181: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.ckpt  = torch.load(
# Assembling -model, -diffuser and -preprocess configs from checkpoint
# USING MODEL CONFIG: self._conf[model][n_extra_block] = 4
# USING MODEL CONFIG: self._conf[model][n_main_block] = 32
# USING MODEL CONFIG: self._conf[model][n_ref_block] = 4
# USING MODEL CONFIG: self._conf[model][d_msa] = 256
# USING MODEL CONFIG: self._conf[model][d_msa_full] = 64
# USING MODEL CONFIG: self._conf[model][d_pair] = 128
# USING MODEL CONFIG: self._conf[model][d_templ] = 64
# USING MODEL CONFIG: self._conf[model][n_head_msa] = 8
# USING MODEL CONFIG: self._conf[model][n_head_pair] = 4
# USING MODEL CONFIG: self._conf[model][n_head_templ] = 4
# USING MODEL CONFIG: self._conf[model][d_hidden] = 32
# USING MODEL CONFIG: self._conf[model][d_hidden_templ] = 32
# USING MODEL CONFIG: self._conf[model][p_drop] = 0.15
# USING MODEL CONFIG: self._conf[model][SE3_param_full] = {'num_layers': 1, 'num_channels': 32, 'num_degrees': 2, 'n_heads': 4, 'div': 4, 'l0_in_features': 8, 'l0_out_features': 8, 'l1_in_features': 3, 'l1_out_features': 2, 'num_edge_features': 32}
# USING MODEL CONFIG: self._conf[model][SE3_param_topk] = {'num_layers': 1, 'num_channels': 32, 'num_degrees': 2, 'n_heads': 4, 'div': 4, 'l0_in_features': 64, 'l0_out_features': 64, 'l1_in_features': 3, 'l1_out_features': 2, 'num_edge_features': 64}
# USING MODEL CONFIG: self._conf[model][freeze_track_motif] = False
# USING MODEL CONFIG: self._conf[model][use_motif_timestep] = True
# USING MODEL CONFIG: self._conf[diffuser][T] = 50
# USING MODEL CONFIG: self._conf[diffuser][b_0] = 0.01
# USING MODEL CONFIG: self._conf[diffuser][b_T] = 0.07
# USING MODEL CONFIG: self._conf[diffuser][schedule_type] = linear
# USING MODEL CONFIG: self._conf[diffuser][so3_type] = igso3
# USING MODEL CONFIG: self._conf[diffuser][crd_scale] = 0.25
# USING MODEL CONFIG: self._conf[diffuser][so3_schedule_type] = linear
# USING MODEL CONFIG: self._conf[diffuser][min_b] = 1.5
# USING MODEL CONFIG: self._conf[diffuser][max_b] = 2.5
# USING MODEL CONFIG: self._conf[diffuser][min_sigma] = 0.02
# USING MODEL CONFIG: self._conf[diffuser][max_sigma] = 1.5
# USING MODEL CONFIG: self._conf[preprocess][sidechain_input] = False
# USING MODEL CONFIG: self._conf[preprocess][motif_sidechain_input] = True
# USING MODEL CONFIG: self._conf[preprocess][d_t1d] = 22
# USING MODEL CONFIG: self._conf[preprocess][d_t2d] = 44
# USING MODEL CONFIG: self._conf[preprocess][prob_self_cond] = 0.5
# USING MODEL CONFIG: self._conf[preprocess][str_self_cond] = True
# USING MODEL CONFIG: self._conf[preprocess][predict_previous] = False
# [2024-08-29 10:14:27,382][rfdiffusion.inference.model_runners][INFO] - Loading checkpoint.
# [2024-08-29 10:14:27,558][rfdiffusion.diffusion][INFO] - Using cached IGSO3.
# /home/coder/.local/lib/python38-conda-cuda/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# Successful diffuser __init__
# [2024-08-29 10:14:27,766][__main__][INFO] - Making design example_outputs/design_motifscaffolding_0
# [2024-08-29 10:14:27,922][rfdiffusion.inference.model_runners][INFO] - Using contig: ['10-40/A163-181/10-40']
# With this beta schedule (linear schedule, beta_0 = 0.04, beta_T = 0.28), alpha_bar_T = 0.00013696050154976547
# [2024-08-29 10:14:27,979][rfdiffusion.inference.model_runners][INFO] - Sequence init: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# /home/coder/.conda/envs/SE3nv/lib/python3.9/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# [2024-08-29 10:14:30,608][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.31
# [2024-08-29 10:14:30,612][rfdiffusion.inference.model_runners][INFO] - Timestep 50, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:31,660][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:14:31,663][rfdiffusion.inference.model_runners][INFO] - Timestep 49, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:32,281][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.29
# [2024-08-29 10:14:32,284][rfdiffusion.inference.model_runners][INFO] - Timestep 48, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:33,613][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.31
# [2024-08-29 10:14:33,616][rfdiffusion.inference.model_runners][INFO] - Timestep 47, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:34,198][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.31
# [2024-08-29 10:14:34,201][rfdiffusion.inference.model_runners][INFO] - Timestep 46, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:36,231][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:14:36,234][rfdiffusion.inference.model_runners][INFO] - Timestep 45, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:36,823][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:14:36,826][rfdiffusion.inference.model_runners][INFO] - Timestep 44, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:39,271][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.28
# [2024-08-29 10:14:39,274][rfdiffusion.inference.model_runners][INFO] - Timestep 43, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:40,227][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.25
# [2024-08-29 10:14:40,230][rfdiffusion.inference.model_runners][INFO] - Timestep 42, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:42,742][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:14:42,745][rfdiffusion.inference.model_runners][INFO] - Timestep 41, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:44,431][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:14:44,435][rfdiffusion.inference.model_runners][INFO] - Timestep 40, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:46,238][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:14:46,241][rfdiffusion.inference.model_runners][INFO] - Timestep 39, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:46,833][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:14:46,837][rfdiffusion.inference.model_runners][INFO] - Timestep 38, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:47,428][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:14:47,431][rfdiffusion.inference.model_runners][INFO] - Timestep 37, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:48,031][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.22
# [2024-08-29 10:14:48,034][rfdiffusion.inference.model_runners][INFO] - Timestep 36, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:50,124][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:14:50,127][rfdiffusion.inference.model_runners][INFO] - Timestep 35, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:52,540][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:14:52,543][rfdiffusion.inference.model_runners][INFO] - Timestep 34, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:54,954][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:14:54,957][rfdiffusion.inference.model_runners][INFO] - Timestep 33, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:57,436][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:14:57,439][rfdiffusion.inference.model_runners][INFO] - Timestep 32, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:14:58,934][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.25
# [2024-08-29 10:14:58,937][rfdiffusion.inference.model_runners][INFO] - Timestep 31, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:00,946][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:15:00,949][rfdiffusion.inference.model_runners][INFO] - Timestep 30, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:01,534][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:15:01,537][rfdiffusion.inference.model_runners][INFO] - Timestep 29, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:02,133][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.22
# [2024-08-29 10:15:02,136][rfdiffusion.inference.model_runners][INFO] - Timestep 28, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:04,682][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.21
# [2024-08-29 10:15:04,685][rfdiffusion.inference.model_runners][INFO] - Timestep 27, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:06,237][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.21
# [2024-08-29 10:15:06,240][rfdiffusion.inference.model_runners][INFO] - Timestep 26, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:06,832][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.20
# [2024-08-29 10:15:06,835][rfdiffusion.inference.model_runners][INFO] - Timestep 25, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:08,111][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.19
# [2024-08-29 10:15:08,114][rfdiffusion.inference.model_runners][INFO] - Timestep 24, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:08,721][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.19
# [2024-08-29 10:15:08,724][rfdiffusion.inference.model_runners][INFO] - Timestep 23, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:11,337][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.19
# [2024-08-29 10:15:11,339][rfdiffusion.inference.model_runners][INFO] - Timestep 22, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:13,742][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.19
# [2024-08-29 10:15:13,745][rfdiffusion.inference.model_runners][INFO] - Timestep 21, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:16,063][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.20
# [2024-08-29 10:15:16,066][rfdiffusion.inference.model_runners][INFO] - Timestep 20, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:17,233][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.19
# [2024-08-29 10:15:17,236][rfdiffusion.inference.model_runners][INFO] - Timestep 19, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:17,830][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.20
# [2024-08-29 10:15:17,833][rfdiffusion.inference.model_runners][INFO] - Timestep 18, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:20,245][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.21
# [2024-08-29 10:15:20,248][rfdiffusion.inference.model_runners][INFO] - Timestep 17, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:22,609][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:15:22,612][rfdiffusion.inference.model_runners][INFO] - Timestep 16, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:24,050][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:15:24,053][rfdiffusion.inference.model_runners][INFO] - Timestep 15, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:24,641][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:15:24,644][rfdiffusion.inference.model_runners][INFO] - Timestep 14, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:26,024][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:15:26,027][rfdiffusion.inference.model_runners][INFO] - Timestep 13, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:26,614][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:15:26,617][rfdiffusion.inference.model_runners][INFO] - Timestep 12, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:28,035][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:15:28,038][rfdiffusion.inference.model_runners][INFO] - Timestep 11, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:30,339][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:15:30,342][rfdiffusion.inference.model_runners][INFO] - Timestep 10, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:31,032][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.22
# [2024-08-29 10:15:31,035][rfdiffusion.inference.model_runners][INFO] - Timestep 9, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:31,623][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:15:31,626][rfdiffusion.inference.model_runners][INFO] - Timestep 8, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:34,033][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.22
# [2024-08-29 10:15:34,036][rfdiffusion.inference.model_runners][INFO] - Timestep 7, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:35,025][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:15:35,028][rfdiffusion.inference.model_runners][INFO] - Timestep 6, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:36,027][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:15:36,030][rfdiffusion.inference.model_runners][INFO] - Timestep 5, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:36,606][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.24
# [2024-08-29 10:15:36,609][rfdiffusion.inference.model_runners][INFO] - Timestep 4, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:38,927][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:15:38,929][rfdiffusion.inference.model_runners][INFO] - Timestep 3, input to next step: ------------------------------------EVNKIKSALLSTNKAVVSL-----------------------
# [2024-08-29 10:15:39,504][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:15:39,506][rfdiffusion.inference.model_runners][INFO] - Timestep 2, input to next step
rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.22
# [2024-08-29 10:24:19,807][rfdiffusion.inference.model_runners][INFO] - Timestep 11, input to next step: ----------------------------------------EVNKIKSALLSTNKAVVSL-----------
# [2024-08-29 10:24:20,403][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.22
# [2024-08-29 10:24:20,405][rfdiffusion.inference.model_runners][INFO] - Timestep 10, input to next step: ----------------------------------------EVNKIKSALLSTNKAVVSL-----------
# [2024-08-29 10:24:21,741][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:24:21,744][rfdiffusion.inference.model_runners][INFO] - Timestep 9, input to next step: ----------------------------------------EVNKIKSALLSTNKAVVSL-----------
# [2024-08-29 10:24:22,304][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:24:22,307][rfdiffusion.inference.model_runners][INFO] - Timestep 8, input to next step: ----------------------------------------EVNKIKSALLSTNKAVVSL-----------
# [2024-08-29 10:24:23,875][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:24:23,878][rfdiffusion.inference.model_runners][INFO] - Timestep 7, input to next step: ----------------------------------------EVNKIKSALLSTNKAVVSL-----------
# [2024-08-29 10:24:24,436][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.22
# [2024-08-29 10:24:24,439][rfdiffusion.inference.model_runners][INFO] - Timestep 6, input to next step: ----------------------------------------EVNKIKSALLSTNKAVVSL-----------
# [2024-08-29 10:24:26,402][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.22
# [2024-08-29 10:24:26,405][rfdiffusion.inference.model_runners][INFO] - Timestep 5, input to next step: ----------------------------------------EVNKIKSALLSTNKAVVSL-----------
# [2024-08-29 10:24:27,804][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.21
# [2024-08-29 10:24:27,807][rfdiffusion.inference.model_runners][INFO] - Timestep 4, input to next step: ----------------------------------------EVNKIKSALLSTNKAVVSL-----------
# [2024-08-29 10:24:28,409][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.22
# [2024-08-29 10:24:28,412][rfdiffusion.inference.model_runners][INFO] - Timestep 3, input to next step: ----------------------------------------EVNKIKSALLSTNKAVVSL-----------
# [2024-08-29 10:24:30,711][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.23
# [2024-08-29 10:24:30,714][rfdiffusion.inference.model_runners][INFO] - Timestep 2, input to next step: ----------------------------------------EVNKIKSALLSTNKAVVSL-----------
# [2024-08-29 10:24:33,440][__main__][INFO] - Finished design in 1.15 minutes
# [2024-08-29 10:24:33,440][__main__][INFO] - Making design example_outputs/design_motifscaffolding_9
# [2024-08-29 10:24:33,596][rfdiffusion.inference.model_runners][INFO] - Using contig: ['10-40/A163-181/10-40']
# With this beta schedule (linear schedule, beta_0 = 0.04, beta_T = 0.28), alpha_bar_T = 0.00013696050154976547
# [2024-08-29 10:24:33,862][rfdiffusion.inference.model_runners][INFO] - Sequence init: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:35,313][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:24:35,316][rfdiffusion.inference.model_runners][INFO] - Timestep 50, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:35,879][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:24:35,882][rfdiffusion.inference.model_runners][INFO] - Timestep 49, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:38,325][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.28
# [2024-08-29 10:24:38,328][rfdiffusion.inference.model_runners][INFO] - Timestep 48, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:39,522][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.29
# [2024-08-29 10:24:39,525][rfdiffusion.inference.model_runners][INFO] - Timestep 47, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:40,114][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:24:40,117][rfdiffusion.inference.model_runners][INFO] - Timestep 46, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:42,259][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:24:42,262][rfdiffusion.inference.model_runners][INFO] - Timestep 45, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:42,869][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.31
# [2024-08-29 10:24:42,872][rfdiffusion.inference.model_runners][INFO] - Timestep 44, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:44,208][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.31
# [2024-08-29 10:24:44,211][rfdiffusion.inference.model_runners][INFO] - Timestep 43, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:44,765][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.32
# [2024-08-29 10:24:44,768][rfdiffusion.inference.model_runners][INFO] - Timestep 42, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:46,418][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:24:46,421][rfdiffusion.inference.model_runners][INFO] - Timestep 41, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:48,776][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.29
# [2024-08-29 10:24:48,779][rfdiffusion.inference.model_runners][INFO] - Timestep 40, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:51,224][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.29
# [2024-08-29 10:24:51,227][rfdiffusion.inference.model_runners][INFO] - Timestep 39, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:51,793][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.27
# [2024-08-29 10:24:51,796][rfdiffusion.inference.model_runners][INFO] - Timestep 38, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:53,220][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.27
# [2024-08-29 10:24:53,223][rfdiffusion.inference.model_runners][INFO] - Timestep 37, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:53,809][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.28
# [2024-08-29 10:24:53,812][rfdiffusion.inference.model_runners][INFO] - Timestep 36, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:56,128][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.27
# [2024-08-29 10:24:56,131][rfdiffusion.inference.model_runners][INFO] - Timestep 35, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:57,309][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.27
# [2024-08-29 10:24:57,311][rfdiffusion.inference.model_runners][INFO] - Timestep 34, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:24:59,710][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.26
# [2024-08-29 10:24:59,713][rfdiffusion.inference.model_runners][INFO] - Timestep 33, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:01,083][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.26
# [2024-08-29 10:25:01,085][rfdiffusion.inference.model_runners][INFO] - Timestep 32, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:01,643][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:25:01,646][rfdiffusion.inference.model_runners][INFO] - Timestep 31, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:02,202][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.29
# [2024-08-29 10:25:02,205][rfdiffusion.inference.model_runners][INFO] - Timestep 30, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:02,761][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.29
# [2024-08-29 10:25:02,764][rfdiffusion.inference.model_runners][INFO] - Timestep 29, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:05,107][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.29
# [2024-08-29 10:25:05,110][rfdiffusion.inference.model_runners][INFO] - Timestep 28, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:05,694][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:25:05,697][rfdiffusion.inference.model_runners][INFO] - Timestep 27, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:07,118][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:25:07,121][rfdiffusion.inference.model_runners][INFO] - Timestep 26, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:07,694][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:25:07,697][rfdiffusion.inference.model_runners][INFO] - Timestep 25, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:09,940][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.29
# [2024-08-29 10:25:09,943][rfdiffusion.inference.model_runners][INFO] - Timestep 24, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:11,117][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:25:11,120][rfdiffusion.inference.model_runners][INFO] - Timestep 23, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:11,710][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:25:11,712][rfdiffusion.inference.model_runners][INFO] - Timestep 22, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:13,008][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:25:13,010][rfdiffusion.inference.model_runners][INFO] - Timestep 21, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:13,600][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.30
# [2024-08-29 10:25:13,603][rfdiffusion.inference.model_runners][INFO] - Timestep 20, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:15,213][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.29
# [2024-08-29 10:25:15,216][rfdiffusion.inference.model_runners][INFO] - Timestep 19, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:15,790][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.28
# [2024-08-29 10:25:15,792][rfdiffusion.inference.model_runners][INFO] - Timestep 18, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:16,360][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.28
# [2024-08-29 10:25:16,363][rfdiffusion.inference.model_runners][INFO] - Timestep 17, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:17,900][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.26
# [2024-08-29 10:25:17,903][rfdiffusion.inference.model_runners][INFO] - Timestep 16, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:18,489][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.26
# [2024-08-29 10:25:18,491][rfdiffusion.inference.model_runners][INFO] - Timestep 15, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:20,211][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.25
# [2024-08-29 10:25:20,214][rfdiffusion.inference.model_runners][INFO] - Timestep 14, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:20,809][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.28
# [2024-08-29 10:25:20,811][rfdiffusion.inference.model_runners][INFO] - Timestep 13, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:21,394][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.27
# [2024-08-29 10:25:21,397][rfdiffusion.inference.model_runners][INFO] - Timestep 12, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:22,814][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.26
# [2024-08-29 10:25:22,818][rfdiffusion.inference.model_runners][INFO] - Timestep 11, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:23,405][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.26
# [2024-08-29 10:25:23,408][rfdiffusion.inference.model_runners][INFO] - Timestep 10, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:24,823][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.25
# [2024-08-29 10:25:24,826][rfdiffusion.inference.model_runners][INFO] - Timestep 9, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:25,403][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.26
# [2024-08-29 10:25:25,406][rfdiffusion.inference.model_runners][INFO] - Timestep 8, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:26,895][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.27
# [2024-08-29 10:25:26,898][rfdiffusion.inference.model_runners][INFO] - Timestep 7, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:27,481][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.27
# [2024-08-29 10:25:27,484][rfdiffusion.inference.model_runners][INFO] - Timestep 6, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:28,987][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.28
# [2024-08-29 10:25:28,990][rfdiffusion.inference.model_runners][INFO] - Timestep 5, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:29,557][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.28
# [2024-08-29 10:25:29,560][rfdiffusion.inference.model_runners][INFO] - Timestep 4, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:32,046][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.29
# [2024-08-29 10:25:32,049][rfdiffusion.inference.model_runners][INFO] - Timestep 3, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:34,316][rfdiffusion.inference.utils][INFO] - Sampled motif RMSD: 0.29
# [2024-08-29 10:25:34,319][rfdiffusion.inference.model_runners][INFO] - Timestep 2, input to next step: ----------------------EVNKIKSALLSTNKAVVSL--------------------------
# [2024-08-29 10:25:37,812][__main__][INFO] - Finished design in 1.07 minutes
# /home/coder/project
